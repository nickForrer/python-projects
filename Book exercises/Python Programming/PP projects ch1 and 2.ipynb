# %%
#ch 1

def chaos():
    x = float(input("enter a num between 0 and 1: "))
    y = float(input("enter another num between 0 and 1: "))
    for i in range(10):
        x = 3.9 * x * (1-x)
        y = 3.9 * y * (1-y)
        print(x, y)
    z = input("press enter to quit")   
chaos()
# Out:
# enter a num between 0 and 1: 0.25
# enter another num between 0 and 1: 0.26
# 0.73125 0.75036
# 0.76644140625 0.73054749456
# 0.6981350104385375 0.7677066257332165
# 0.8218958187902304 0.6954993339002887
# 0.5708940191969317 0.8259420407337192
# 0.9553987483642099 0.5606709657211202
# 0.166186721954413 0.9606442322820199
# 0.5404179120617926 0.14744687593470315
# 0.9686289302998042 0.49025454937601765
# 0.11850901017563877 0.9746296021493285

# %%
def main():
    
    print("This converts a temp in celcius to farenheit")
    celsius = 0    
    for i in range(11):    
        fahrenheit = 9/5 * celsius + 32
        print("The temperature is", celsius, "degrees Celcius and", fahrenheit, "degrees Fahrenheit.")  
        celsius = celsius + 10

main()
# Out:
# This converts a temp in celcius to farenheit
# The temperature is 0 degrees Celcius and 32.0 degrees Fahrenheit.
# The temperature is 10 degrees Celcius and 50.0 degrees Fahrenheit.
# The temperature is 20 degrees Celcius and 68.0 degrees Fahrenheit.
# The temperature is 30 degrees Celcius and 86.0 degrees Fahrenheit.
# The temperature is 40 degrees Celcius and 104.0 degrees Fahrenheit.
# The temperature is 50 degrees Celcius and 122.0 degrees Fahrenheit.
# The temperature is 60 degrees Celcius and 140.0 degrees Fahrenheit.
# The temperature is 70 degrees Celcius and 158.0 degrees Fahrenheit.
# The temperature is 80 degrees Celcius and 176.0 degrees Fahrenheit.
# The temperature is 90 degrees Celcius and 194.0 degrees Fahrenheit.
# The temperature is 100 degrees Celcius and 212.0 degrees Fahrenheit.

# %%
for i in range(1):
    print(i)
# Out:
# 0

# %%
def main():
    
    print("This converts a temp in celcius to farenheit")
    for i in range(5):    
        
        celsius = float(input("What is the Celsius temperature? "))
        fahrenheit = 9/5 * celsius + 32
        print("The temperature is", fahrenheit, "degrees Fahrenheit.")  
        

main()

# %%
#futval

def main():
    print("This program calculates the future value")
    print("of a n-year investment.")

    principal = float(input("Enter the initial principal: "))
    apr = float(input("Enter the annual interest rate: "))
    years = int(input("enter the number of years: "))
    add = float(input("enter the num to add to principle each year: "))
    for _ in range(years):
        print(principal)
        principal = (principal + add) * (1 + apr)
        

    print("The value in ", years,"years is:", principal)


main()
# Out:
# This program calculates the future value
# of a n-year investment.
# Enter the initial principal: 1000
# Enter the annual interest rate: 0.05
# enter the number of years: 2
# enter the num to add to principle each year: 100
# 1000.0
# 1155.0
# The value in  2 years is: 1317.75

# %%
def main():
    print("This program calculates the future value")
    print("of a n-year investment.")

    principal = float(input("Enter the initial principal: "))
    rate = float(input("Enter the annual interest rate: "))
    periods = int(input("enter the num of times per year its cal"))
    years = int(input("enter the number of years: "))
    for _ in range(years*periods):
        print(principal)
        principal = (principal) * (1 + rate/periods)
        

    print("The value in ", years,"years is:", principal)


main()
# Out:
# This program calculates the future value
# of a n-year investment.
# Enter the initial principal: 1000
# Enter the annual interest rate: 0.05
# enter the num of times per year its cal4
# enter the number of years: 2
# 1000.0
# 1012.5
# 1025.15625
# 1037.970703125
# 1050.9453369140624
# 1064.0821536254882
# 1077.3831805458067
# 1090.8504703026292
# The value in  2 years is: 1104.486101181412

# %%
def main():
    
        print("This converts a temp in farenheit to celcius")    
        
        fahrenheit = float(input("What is the Farenheit temperature? "))
        celcius = (5/9) * (fahrenheit - 32)
        print("The temperature is", celcius, "degrees celcius.")  
        

main()
# Out:
# This converts a temp in farenheit to celcius
# What is the Farenheit temperature? 32
# The temperature is 0.0 degrees celcius.

# %%
def conver():
    km = float(input("enter distance in KM: "))
    miles = km*0.62
    print("the distance in miles is",miles)
    
conver()
# Out:
# enter distance in KM: 100
# the distance in miles is 62.0

# %%
def mean():
    x = int(input("enter a num: "))
    y = int(input("enter a num: "))
    z = int(input("enter a num: "))
    print("the mean is: ", (x + y + z )/3)
    
mean()
# Out:
# enter a num: 2
# enter a num: 3
# enter a num: 4
# the mean is:  3.0

# %%
#for aribtrary num of vals

def mean():
    n = int(input("pls enter num of vals"))
    total = 0
    for i in range(n):
        val = int(input("enter a num: "))
        total = total + val
    result = total/n
    print(result)
    
mean()

# %%
def mean():
    total = 0
    count = 0
    while True:
        val = (input("enter a num: <escape to quit>"))
        if val == '':
            break
        else:
            intconv = int(val)
        total = total + intconv
        count = count + 1
    result = total/count
    print("the mean value is", result)
    
mean()
# Out:
# enter a num: <escape to quit>2
# enter a num: <escape to quit>3
# enter a num: <escape to quit>4
# enter a num: <escape to quit>5
# enter a num: <escape to quit>
# the mean value is 3.5
