# %%
#Libraries, packages and modules

#python standard library is the mother of all the specialized prewritten code

#each standard data type is an instance of a class and is an object

x = 3
print(type(x))
# Out:
# <class 'int'>

# %%
x = 'howdy'
print(type(x))
# Out:
# <class 'str'>

# %%
#the dir() method displays a list of all the attributes associated with a type
#dir(str)

print(type(x), x.isalpha(), x.upper())
# Out:
# <class 'str'> True HOWDY

# %%
#using help func - gives info on each class method
#help(str)

#help and dir are two of the PSL builtin funcs

# %%
#libraries > packages > modules

from math import pi, sqrt
#dir(math)

print(sqrt(pi))
# Out:
# 1.7724538509055159

# %%
#create your own module - just a txt file with a .py ext

import datetime as dt

def to_date(any_str):
    """ convert mm/dd/yy or mm/dd/yyyy string to datetime.date or None if invalid date"""
    try:
        if len(any_str) == 10:
            the_date = dt.datetime.strptime(any_str, '%m/%d%Y').date()
        else:
            the_date = dt.datetime.strptime(any_str, '%m/%d%Y').date()
    except (ValueError, TypeError):
            the_date = None
    return the_date

def to_curr(anynum, len =0):
    """ returns a num as a string with $ and commas. Length is optional"""
    s = 'Invalid amount'
    try:
        x = float(anynum)
    except ValueError:
        x = none
    if isinstance(x,float):
        s = '$' + f"{x:,.2f}"
        if len > 0:
            s=s.rjust(len)
    return s

# %%
#import all the code from myfunc.py as my
import myfunc as my

from myfunc import to_date, my_curr

#need dates in this code
from datetime import datetime as dt


#some simple test data

string_date = "12/13/2019"
#print(myfunc.to_date(string_date))

dollar_amt=12345.678
print(my.to_curr(dollar_amt))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 4
#       1 #import all the code from myfunc.py as my
#       2 import myfunc as my
# ----> 4 from myfunc import to_date, my_curr
#       6 #need dates in this code
#       7 from datetime import datetime as dt
#
# ImportError: cannot import name 'to_date' from 'myfunc' (/Users/nicholasforrer/Desktop/code/TPOP /myfunc.py)
